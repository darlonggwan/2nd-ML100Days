# %% [markdown]
# # 作業1：
# ## 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# [Air quality in northern Taiwan](https://www.kaggle.com/nelsonchu/air-quality-in-northern-taiwan)
# ### 1. 你選的這組資料為何重要
# 檢視目前空氣品質
# ### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# This data is from Environmental Protection Administration, Executive Yuan, R.O.C. (Taiwan).
# [光化測站open data](https://taqm.epa.gov.tw/taqm/tw/YearlyDataDownload.aspx)
# ### 3. 蒐集而來的資料型態為何
# 這篇是屬於數值類型的資料 (可以用 PM2.5 或 UV(紫外線) 其中之一當作目標資料)
# ### 4. 這組資料想解決的問題如何評估
# 用回歸來做, 因此也用回歸類的評估方式就好了
# 如 MSE (Mean Square Error, 平均方差)
# 這份資料的特色, 是資料是隨著時間連續變化的
# 因此可以用作時序類型的工具來處理, 例如: LSTM / GRU

# %% [markdown]
# # 作業2：
# ## 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# ### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 花更少的汽油，載更多的乘客賺更多的費用
# 假設載客數及收入會跟每日不同時段有關
# ### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 收據列印表，可記錄時間、費用
# 加油發票
# ### 3. 蒐集而來的資料型態為何
# 結構化表格，每台車的收據紀錄、及加油發票紀錄
# 也是屬於數值類型的資料
# ### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 不怎麼懂....應該也是回歸吧

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    輸入：
    (1) y：實際值(List)
    (2) yp：預測值(List)
    回傳：均方誤差(List)
    https://zh.wikipedia.org/wiki/%E5%9D%87%E6%96%B9%E8%AF%AF%E5%B7%AE
    """
    return sum((y - yp) ** 2) / len(y)

# %%
def mean_absolute_error(y, yp):
    """
    輸入：
    (1) y：實際值(List)
    (2) yp：預測值(List)
    回傳：平均絕對誤差(List)
    https://en.wikipedia.org/wiki/Mean_absolute_error
    https://blog.csdn.net/capecape/article/details/78623897
    """
    return sum(abs(y - yp)) / len(y)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 226.198
# The Mean absolute error is 12.392
